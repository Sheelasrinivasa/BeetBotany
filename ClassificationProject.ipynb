# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
plantdata = pd.read_csv(os.path.join('PlantData.csv'))
plantdata = plantdata.dropna()
plantdata.head()
# Out:
#     city_ascii      lat      lng  Humidity  Cloudiness  Temperature  \
# 0    Malisheve  42.4822  20.7458      77.0         0.0        60.80
# 1      Prizren  42.2139  20.7397      77.0         0.0        60.80
# 2  Zubin Potok  42.9144  20.6897      77.0         0.0        60.80
# 3     Kamenice  42.5781  21.5803      77.0         0.0        63.66
# 4         Viti  42.3214  21.3583      77.0         0.0        63.54
#
#    WindSpeed            Beets    Carrots    Lettuce    Parsley  \
# 0       1.12  Partially ideal  Not ideal  Not ideal  Not ideal
# 1       1.12  Partially ideal  Not ideal  Not ideal  Not ideal
# 2       1.12  Partially ideal  Not ideal  Not ideal  Not ideal
# 3       1.12  Partially ideal  Not ideal  Not ideal  Not ideal
# 4       1.12  Partially ideal  Not ideal  Not ideal  Not ideal
#
#             Radish    Spinach           Turnip
# 0  Partially ideal  Not ideal  Partially ideal
# 1  Partially ideal  Not ideal  Partially ideal
# 2  Partially ideal  Not ideal  Partially ideal
# 3  Partially ideal  Not ideal  Partially ideal
# 4  Partially ideal  Not ideal  Partially ideal

# %%
beetsdata = plantdata.drop(["city_ascii","Carrots","Lettuce","Parsley","Radish","Spinach","Turnip"],axis=1)
beetsdata.head()
# Out:
#        lat      lng  Humidity  Cloudiness  Temperature  WindSpeed  \
# 0  42.4822  20.7458      77.0         0.0        60.80       1.12
# 1  42.2139  20.7397      77.0         0.0        60.80       1.12
# 2  42.9144  20.6897      77.0         0.0        60.80       1.12
# 3  42.5781  21.5803      77.0         0.0        63.66       1.12
# 4  42.3214  21.3583      77.0         0.0        63.54       1.12
#
#              Beets
# 0  Partially ideal
# 1  Partially ideal
# 2  Partially ideal
# 3  Partially ideal
# 4  Partially ideal

# %%
help(plantdata.drop)
# Out:
# Help on method drop in module pandas.core.frame:
#
# drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index, columns : single label or list-like
#         Alternative to specifying axis (``labels, axis=1``
#         is equivalent to ``columns=labels``).
#
#         .. versionadded:: 0.21.0
#     level : int or level name, optional
#         For MultiIndex, level from which the labels will be removed.
#     inplace : bool, default False
#         If True, do operation inplace and return None.
#     errors : {'ignore', 'raise'}, default 'raise'
#         If 'ignore', suppress error and only existing labels are
#         dropped.
#
#     Returns
#     -------
#     dropped : pandas.DataFrame
#
#     See Also
#     --------
#     DataFrame.loc : Label-location based indexer for selection by label.
#     DataFrame.dropna : Return DataFrame with labels on given axis omitted
#         where (all or any) data are missing
#     DataFrame.drop_duplicates : Return DataFrame with duplicate rows
#         removed, optionally only considering certain columns
#     Series.drop : Return Series with specified index labels removed.
#
#     Raises
#     ------
#     KeyError
#         If none of the labels are found in the selected axis
#
#     Examples
#     --------
#     >>> df = pd.DataFrame(np.arange(12).reshape(3,4),
#     ...                   columns=['A', 'B', 'C', 'D'])
#     >>> df
#        A  B   C   D
#     0  0  1   2   3
#     1  4  5   6   7
#     2  8  9  10  11
#
#     Drop columns
#
#     >>> df.drop(['B', 'C'], axis=1)
#        A   D
#     0  0   3
#     1  4   7
#     2  8  11
#
#     >>> df.drop(columns=['B', 'C'])
#        A   D
#     0  0   3
#     1  4   7
#     2  8  11
#
#     Drop a row by index
#
#     >>> df.drop([0, 1])
#        A  B   C   D
#     2  8  9  10  11
#
#     Drop columns and/or rows of MultiIndex DataFrame
#
#     >>> midx = pd.MultiIndex(levels=[['lama', 'cow', 'falcon'],
#     ...                              ['speed', 'weight', 'length']],
#     ...                      labels=[[0, 0, 0, 1, 1, 1, 2, 2, 2],
#     ...                              [0, 1, 2, 0, 1, 2, 0, 1, 2]])
#     >>> df = pd.DataFrame(index=midx, columns=['big', 'small'],
#     ...                   data=[[45, 30], [200, 100], [1.5, 1], [30, 20],
#     ...                         [250, 150], [1.5, 0.8], [320, 250],
#     ...                         [1, 0.8], [0.3,0.2]])
#     >>> df
#                     big     small
#     lama    speed   45.0    30.0
#             weight  200.0   100.0
#             length  1.5     1.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#             length  1.5     0.8
#     falcon  speed   320.0   250.0
#             weight  1.0     0.8
#             length  0.3     0.2
#
#     >>> df.drop(index='cow', columns='small')
#                     big
#     lama    speed   45.0
#             weight  200.0
#             length  1.5
#     falcon  speed   320.0
#             weight  1.0
#             length  0.3
#
#     >>> df.drop(index='length', level=1)
#                     big     small
#     lama    speed   45.0    30.0
#             weight  200.0   100.0
#     cow     speed   30.0    20.0
#             weight  250.0   150.0
#     falcon  speed   320.0   250.0
#             weight  1.0     0.8

# %%
# Assign X (data) and y (target)
beets_X = beetsdata.drop("Beets", axis=1)
beets_y = beetsdata["Beets"]
print(beets_X.shape, beets_y.shape)
# Out:
# (12892, 6) (12892,)

# %% [markdown]
# Split our data into training and testing

# %%
from sklearn.model_selection import train_test_split

beets_X_train, beets_X_test, beets_y_train, beets_y_test = train_test_split(beets_X,beets_y, random_state=1, stratify=beets_y)

# %% [markdown]
# Create a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
PlantingModel = LogisticRegression()
PlantingModel
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# Fit (train) or model using the training data

# %%
PlantingModel.fit(beets_X_train,beets_y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# Validate the model using the test data

# %%
print(f"Training Data Score: {PlantingModel.score(beets_X_train, beets_y_train)}")
print(f"Testing Data Score: {PlantingModel.score(beets_X_test, beets_y_test)}")
# Out:
# Training Data Score: 0.9252249457027614
# Testing Data Score: 0.9273968352466646

# %% [markdown]
# Make predictions

# %%
predictions = PlantingModel.predict(beets_X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {beets_y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['Partially ideal' 'Not ideal' 'Not ideal' 'Partially ideal' 'Not ideal'
#  'Not ideal' 'Not ideal' 'Not ideal' 'Partially ideal' 'Not ideal']
# First 10 Actual labels: ['Partially ideal', 'Not ideal', 'Not ideal', 'Partially ideal', 'Not ideal', 'Not ideal', 'Not ideal', 'Not ideal', 'Partially ideal', 'Not ideal']

# %%
pd.DataFrame({"Prediction": predictions, "Actual":beets_y_test}).reset_index(drop=True)
# Out:
#            Prediction           Actual
# 0     Partially ideal  Partially ideal
# 1           Not ideal        Not ideal
# 2           Not ideal        Not ideal
# 3     Partially ideal  Partially ideal
# 4           Not ideal        Not ideal
# 5           Not ideal        Not ideal
# 6           Not ideal        Not ideal
# 7           Not ideal        Not ideal
# 8     Partially ideal  Partially ideal
# 9           Not ideal        Not ideal
# 10          Not ideal        Not ideal
# 11          Not ideal        Not ideal
# 12          Not ideal        Not ideal
# 13          Not ideal        Not ideal
# 14          Not ideal        Not ideal
# 15    Partially ideal  Partially ideal
# 16          Not ideal        Not ideal
# 17          Not ideal        Not ideal
# 18    Partially ideal  Partially ideal
# 19          Not ideal        Not ideal
# 20          Not ideal        Not ideal
# 21          Not ideal        Not ideal
# 22    Partially ideal  Partially ideal
# 23          Not ideal        Not ideal
# 24          Not ideal  Partially ideal
# 25          Not ideal        Not ideal
# 26          Not ideal        Not ideal
# 27          Not ideal        Not ideal
# 28          Not ideal        Not ideal
# 29          Not ideal        Not ideal
# ...               ...              ...
# 3193        Not ideal        Not ideal
# 3194        Not ideal        Not ideal
# 3195        Not ideal  Partially ideal
# 3196        Not ideal        Not ideal
# 3197        Not ideal        Not ideal
# 3198  Partially ideal  Partially ideal
# 3199  Partially ideal  Partially ideal
# 3200        Not ideal        Not ideal
# 3201  Partially ideal  Partially ideal
# 3202        Not ideal        Not ideal
# 3203        Not ideal        Not ideal
# 3204        Not ideal        Not ideal
# 3205        Not ideal        Not ideal
# 3206  Partially ideal  Partially ideal
# 3207        Not ideal        Not ideal
# 3208        Not ideal        Not ideal
# 3209  Partially ideal  Partially ideal
# 3210        Not ideal        Not ideal
# 3211        Not ideal        Not ideal
# 3212        Not ideal        Not ideal
# 3213        Not ideal        Not ideal
# 3214        Not ideal        Not ideal
# 3215  Partially ideal  Partially ideal
# 3216        Not ideal        Not ideal
# 3217        Not ideal        Not ideal
# 3218  Partially ideal  Partially ideal
# 3219        Not ideal        Not ideal
# 3220  Partially ideal  Partially ideal
# 3221        Not ideal        Not ideal
# 3222        Not ideal        Not ideal
#
# [3223 rows x 2 columns]

# %% [markdown]
# #One hot encoder

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(beets_y_train)
encoded_y = label_encoder.transform(beets_y_train)

# %%
for label, original_class in zip(encoded_y, beets_y_train):
    print('Original Class: ' + str(original_class))
    print('Encoded Label: ' + str(label))
    print('-' * 12)
# Out:
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Ideal
# Encoded Label: 0
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Ideal
# Encoded Label: 0
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Ideal
# Encoded Label: 0
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Ideal
# Encoded Label: 0
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Ideal
# Encoded Label: 0
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Ideal
# Encoded Label: 0
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# ...
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Ideal
# Encoded Label: 0
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------
# Original Class: Partially ideal
# Encoded Label: 2
# ------------
# Original Class: Not ideal
# Encoded Label: 1
# ------------

# %%
plantpredictdata = pd.read_csv(os.path.join('Results_2018_10_02_Oct_10.csv'))
plantpredictdata = plantpredictdata.dropna()
plantpredictdata = plantpredictdata.drop(["city_ascii","CurrentDate","CurrentTime","country"],axis=1)
plantpredictdata.head()
# Out:
#        lat      lng  WindSpeed  Humidity  Cloudiness  Temperature
# 0  42.4822  20.7458      11.41      55.0        75.0        64.40
# 1  42.2139  20.7397      11.41      55.0        75.0        64.40
# 2  42.9144  20.6897      11.41      55.0        75.0        64.40
# 3  42.5781  21.5803      11.41      55.0        75.0        69.17
# 4  42.3214  21.3583      11.41      55.0        75.0        68.95

# %%
FinalTest = PlantingModel.predict(plantpredictdata)
plantpredictdata['BeetPredict'] = FinalTest
plantpredictdata.head()
# Out:
#        lat      lng  WindSpeed  Humidity  Cloudiness  Temperature BeetPredict
# 0  42.4822  20.7458      11.41      55.0        75.0        64.40   Not ideal
# 1  42.2139  20.7397      11.41      55.0        75.0        64.40   Not ideal
# 2  42.9144  20.6897      11.41      55.0        75.0        64.40   Not ideal
# 3  42.5781  21.5803      11.41      55.0        75.0        69.17   Not ideal
# 4  42.3214  21.3583      11.41      55.0        75.0        68.95   Not ideal

# %%
pd.DataFrame({"Prediction": predictions, "Actual":beets_y_test}).reset_index(drop=True)
